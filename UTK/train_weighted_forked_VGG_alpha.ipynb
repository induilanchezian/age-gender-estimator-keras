# %% [markdown]
# UTKFace dataset is a large-scale face dataset with long age span (range from 0 to 116 years old). The dataset consists of over 20,000 face images with annotations of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc. This dataset could be used on a variety of tasks, e.g., face detection, age estimation, age progression/regression, landmark localization, etc.
#
# The labels of each face image is embedded in the file name, formated like [age]_[gender]_[race]_[date&time].jpg
#
# [age] is an integer from 0 to 116, indicating the age
# [gender] is either 0 (male) or 1 (female)
# [race] is an integer from 0 to 4, denoting White, Black, Asian, Indian, and Others (like Hispanic, Latino, Middle Eastern).
# [date&time] is in the format of yyyymmddHHMMSSFFF, showing the date and time an image was collected to UTKFace

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%bash
# ls data
# # it seems crop_part1 conists of subset of data contained in UTKFace so we won't be using it.
# Out:
# UTKFace
# UTKFace.tar.gz

# %% [markdown]
# **Constants**

# %%
DATA_DIR = "data/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))

# %%
attributes = list(map(parse_filepath, files))
# Out:
# data/UTKFace/61_1_20170109142408075.jpg.chip.jpg
# data/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# data/UTKFace/39_1_20170116174525125.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  26.0  female  indian  data/UTKFace/26_1_3_20170119180945883.jpg.chip...
# 1  29.0    male   black  data/UTKFace/29_0_1_20170116195112736.jpg.chip...
# 2  62.0    male   asian  data/UTKFace/62_0_2_20170112223958141.jpg.chip...
# 3  22.0    male   asian  data/UTKFace/22_0_2_20170116175910195.jpg.chip...
# 4  16.0  female  others  data/UTKFace/16_1_4_20170103233406635.jpg.chip...

# %% [markdown]
# # Exploratory analysis

# %%
df.describe()
# Out:
#                 age
# count  23705.000000
# mean      33.300907
# std       19.885708
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %% [markdown]
# From the plot we can see that most of people are within 10 and 55 years of age. Most probably, we'll discard the dataset for rest of the ages.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')

# %% [markdown]
# It turns out that there are many images of *white male* and *while female*. images from *others* category are very less in number compared to rest of the categories especially *white* category.
# Let's analyze our data from *age* perspective.

# %%
df['age'].hist()

# %%
df['age'].describe()
# Out:
# count    23705.000000
# mean        33.300907
# std         19.885708
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64

# %%
df = df[(df['age'] > 10) & (df['age'] < 65)]

# %% [markdown]
# # Data prep

# %%
p = np.random.RandomState(seed=10).permutation(len(df))
print(p)
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# [15086  9370   344 ... 17728  7293 17673]
# (9079, 3891, 5559, 64.0)

# %%
from keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, ages, races, genders = [], [], [], []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, age, race, gender = r['file'], r['age'], r['race_id'], r['gender_id']
            im = Image.open(file)
            im = im.resize((IM_WIDTH, IM_HEIGHT))
            im = np.array(im) / 255.0
            images.append(im)
            ages.append(age / max_age)
            races.append(to_categorical(race, len(RACE_ID_MAP)))
            genders.append(to_categorical(gender, 2))
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
                images, ages, races, genders = [], [], [], []
        if not for_training:
            break
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Model training

# %%
from keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout, Flatten
from keras.optimizers import SGD, RMSprop
from keras.models import Model
from keras import applications

def conv_block(inp, filters=32, bn=True, pool=True):
    _ = Conv2D(filters=filters, kernel_size=3, activation='relu')(inp)
    if bn:
        _ = BatchNormalization()(_)
    if pool:
        _ = MaxPool2D()(_)
    return _

vgg_model = applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_shape=(IM_HEIGHT, IM_WIDTH, 3))

#Branching out earlier in the model for race
layer_dict = dict([(layer.name, layer) for layer in vgg_model.layers])
x_race = layer_dict['block4_pool'].output
#x_race = Conv2D(filters=512, kernel_size=3, activation='relu')(x_race)
#x_race = Conv2D(filters=512, kernel_size=3, activation='relu')(x_race)
#x_race = Conv2D(filters=512, kernel_size=1, activation='relu')(x_race)
#x_race = MaxPool2D()(x_race)
x_race = Flatten()(x_race)

#More layers till the last layer in VGG for age and gender
x = vgg_model.output
x = Flatten()(x)
#x = Dense(4096, activation='relu')(x)

# for age calculation
age = Dense(units=128, activation='relu')(x)
age_output = Dense(units=1, activation='sigmoid', name='age_output')(age)

# for race prediction
race = Dense(units=128, activation='relu')(x_race)
race_output = Dense(units=len(RACE_ID_MAP), activation='softmax', name='race_output')(race)

# for gender prediction
gender = Dense(units=128, activation='relu')(x)
gender_output = Dense(units=len(GENDER_ID_MAP), activation='softmax', name='gender_output')(gender)

alpha1 = 1.
alpha2 = 0.1

model = Model(inputs=vgg_model.input, outputs=[age_output, race_output, gender_output])
opt = RMSprop(lr=1e-5)
model.compile(optimizer=opt, 
              loss={'age_output': 'mse', 'race_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
              loss_weights={'age_output': 0, 'race_output': alpha2, 'gender_output': alpha1},
              metrics={'age_output': 'mae', 'race_output': 'accuracy', 'gender_output': 'accuracy'})
# model.summary()

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 64
valid_batch_size = 64
train_gen = get_data_generator(df, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df, valid_idx, for_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./models/{}_{}_forked_VGG_model.h5".format(alpha1, alpha2), monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=10,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 52s 368ms/step - loss: 0.4336 - age_output_loss: 0.0745 - race_output_loss: 1.1462 - gender_output_loss: 0.3190 - age_output_mean_absolute_error: 0.2369 - race_output_acc: 0.5923 - gender_output_acc: 0.8600 - val_loss: 0.2593 - val_age_output_loss: 0.0775 - val_race_output_loss: 0.8267 - val_gender_output_loss: 0.1766 - val_age_output_mean_absolute_error: 0.2414 - val_race_output_acc: 0.7138 - val_gender_output_acc: 0.9349
# Epoch 2/10
# 141/141 [==============================] - 46s 329ms/step - loss: 0.2291 - age_output_loss: 0.0818 - race_output_loss: 0.6324 - gender_output_loss: 0.1659 - age_output_mean_absolute_error: 0.2480 - race_output_acc: 0.7790 - gender_output_acc: 0.9397 - val_loss: 0.2972 - val_age_output_loss: 0.0908 - val_race_output_loss: 0.7378 - val_gender_output_loss: 0.2234 - val_age_output_mean_absolute_error: 0.2621 - val_race_output_acc: 0.7497 - val_gender_output_acc: 0.9141
# Epoch 3/10
# 141/141 [==============================] - 46s 327ms/step - loss: 0.1625 - age_output_loss: 0.0910 - race_output_loss: 0.4179 - gender_output_loss: 0.1207 - age_output_mean_absolute_error: 0.2621 - race_output_acc: 0.8590 - gender_output_acc: 0.9588 - val_loss: 0.2196 - val_age_output_loss: 0.1025 - val_race_output_loss: 0.7340 - val_gender_output_loss: 0.1462 - val_age_output_mean_absolute_error: 0.2790 - val_race_output_acc: 0.7742 - val_gender_output_acc: 0.9474
# Epoch 4/10
# 141/141 [==============================] - 46s 327ms/step - loss: 0.1151 - age_output_loss: 0.0948 - race_output_loss: 0.2867 - gender_output_loss: 0.0865 - age_output_mean_absolute_error: 0.2669 - race_output_acc: 0.9040 - gender_output_acc: 0.9748 - val_loss: 0.2195 - val_age_output_loss: 0.1026 - val_race_output_loss: 0.8760 - val_gender_output_loss: 0.1319 - val_age_output_mean_absolute_error: 0.2781 - val_race_output_acc: 0.7336 - val_gender_output_acc: 0.9609
# Epoch 5/10
# 141/141 [==============================] - 46s 327ms/step - loss: 0.0840 - age_output_loss: 0.1000 - race_output_loss: 0.1923 - gender_output_loss: 0.0648 - age_output_mean_absolute_error: 0.2737 - race_output_acc: 0.9377 - gender_output_acc: 0.9832 - val_loss: 0.3056 - val_age_output_loss: 0.1092 - val_race_output_loss: 0.7966 - val_gender_output_loss: 0.2260 - val_age_output_mean_absolute_error: 0.2873 - val_race_output_acc: 0.7706 - val_gender_output_acc: 0.9273
# Epoch 6/10
# 141/141 [==============================] - 47s 330ms/step - loss: 0.0581 - age_output_loss: 0.1084 - race_output_loss: 0.1219 - gender_output_loss: 0.0459 - age_output_mean_absolute_error: 0.2848 - race_output_acc: 0.9633 - gender_output_acc: 0.9883 - val_loss: 0.2368 - val_age_output_loss: 0.1120 - val_race_output_loss: 0.8604 - val_gender_output_loss: 0.1508 - val_age_output_mean_absolute_error: 0.2891 - val_race_output_acc: 0.7737 - val_gender_output_acc: 0.9581
# Epoch 7/10
# 141/141 [==============================] - 46s 326ms/step - loss: 0.0411 - age_output_loss: 0.1182 - race_output_loss: 0.0936 - gender_output_loss: 0.0317 - age_output_mean_absolute_error: 0.2981 - race_output_acc: 0.9732 - gender_output_acc: 0.9917 - val_loss: 0.3504 - val_age_output_loss: 0.1192 - val_race_output_loss: 1.1027 - val_gender_output_loss: 0.2401 - val_age_output_mean_absolute_error: 0.2978 - val_race_output_acc: 0.7727 - val_gender_output_acc: 0.9391
# Epoch 8/10
# 141/141 [==============================] - 46s 330ms/step - loss: 0.0320 - age_output_loss: 0.1255 - race_output_loss: 0.0695 - gender_output_loss: 0.0251 - age_output_mean_absolute_error: 0.3077 - race_output_acc: 0.9813 - gender_output_acc: 0.9920 - val_loss: 0.2702 - val_age_output_loss: 0.1203 - val_race_output_loss: 0.9827 - val_gender_output_loss: 0.1720 - val_age_output_mean_absolute_error: 0.2990 - val_race_output_acc: 0.7823 - val_gender_output_acc: 0.9555
# Epoch 9/10
# 141/141 [==============================] - 47s 333ms/step - loss: 0.0256 - age_output_loss: 0.1305 - race_output_loss: 0.0542 - gender_output_loss: 0.0202 - age_output_mean_absolute_error: 0.3142 - race_output_acc: 0.9869 - gender_output_acc: 0.9949 - val_loss: 0.3014 - val_age_output_loss: 0.1305 - val_race_output_loss: 1.1406 - val_gender_output_loss: 0.1873 - val_age_output_mean_absolute_error: 0.3134 - val_race_output_acc: 0.7818 - val_gender_output_acc: 0.9568
# Epoch 10/10
# 141/141 [==============================] - 47s 331ms/step - loss: 0.0208 - age_output_loss: 0.1295 - race_output_loss: 0.0437 - gender_output_loss: 0.0164 - age_output_mean_absolute_error: 0.3123 - race_output_acc: 0.9900 - gender_output_acc: 0.9959 - val_loss: 0.3170 - val_age_output_loss: 0.1269 - val_race_output_loss: 1.1546 - val_gender_output_loss: 0.2015 - val_age_output_mean_absolute_error: 0.3077 - val_race_output_acc: 0.7875 - val_gender_output_acc: 0.9555

# %%
def  plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['race_output_acc'], label='Race Train accuracy')
    axes[0].plot(history.history['val_race_output_acc'], label='Race Val accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()
    
    axes[1].plot(history.history['gender_output_acc'], label='Gender Train accuracy')
    axes[1].plot(history.history['val_gender_output_acc'], label='Gener Val accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['age_output_mean_absolute_error'], label='Age Train MAE')
    axes[2].plot(history.history['val_age_output_mean_absolute_error'], label='Age Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
dict(zip(model.metrics_names, model.evaluate_generator(test_gen, steps=len(test_idx)//128)))
# Out:
# {'loss': 0.3460230827331543,
#  'age_output_loss': 0.12434408415195554,
#  'race_output_loss': 1.1318515026292135,
#  'gender_output_loss': 0.23283793170784794,
#  'age_output_mean_absolute_error': 0.3047408530878466,
#  'race_output_acc': 0.7936046511627907,
#  'gender_output_acc': 0.9522165697674418}

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
x_test, (age_true, race_true, gender_true)= next(test_gen)
age_pred, race_pred, gender_pred = model.predict_on_batch(x_test)

# %%
race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)
age_true = age_true * max_age
age_pred = age_pred * max_age

# %%
from sklearn.metrics import classification_report
print("Classification report for race")
print(classification_report(race_true, race_pred))

print("\nClassification report for gender")
print(classification_report(gender_true, gender_pred))
# Out:
# Classification report for race
#               precision    recall  f1-score   support
#
#            0       0.75      0.91      0.82        43
#            1       0.89      0.94      0.91        33
#            2       0.83      0.67      0.74        15
#            3       0.81      0.95      0.88        22
#            4       0.33      0.07      0.11        15
#
#     accuracy                           0.80       128
#    macro avg       0.72      0.71      0.69       128
# weighted avg       0.76      0.80      0.76       128
#
#
# Classification report for gender
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        67
#            1       0.95      0.97      0.96        61
#
#     accuracy                           0.96       128
#    macro avg       0.96      0.96      0.96       128
# weighted avg       0.96      0.96      0.96       128

# %%
import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(x_test[img_idx])
    ax.set_title('a:{}, g:{}, r:{}'.format(int(age_pred[img_idx]), ID_GENDER_MAP[gender_pred[img_idx]], ID_RACE_MAP[race_pred[img_idx]]))
    ax.set_xlabel('a:{}, g:{}, r:{}'.format(int(age_true[img_idx]), ID_GENDER_MAP[gender_true[img_idx]], ID_RACE_MAP[race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
