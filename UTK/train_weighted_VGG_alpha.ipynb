# %% [markdown]
# UTKFace dataset is a large-scale face dataset with long age span (range from 0 to 116 years old). The dataset consists of over 20,000 face images with annotations of age, gender, and ethnicity. The images cover large variation in pose, facial expression, illumination, occlusion, resolution, etc. This dataset could be used on a variety of tasks, e.g., face detection, age estimation, age progression/regression, landmark localization, etc.
#
# The labels of each face image is embedded in the file name, formated like [age]_[gender]_[race]_[date&time].jpg
#
# [age] is an integer from 0 to 116, indicating the age
# [gender] is either 0 (male) or 1 (female)
# [race] is an integer from 0 to 4, denoting White, Black, Asian, Indian, and Others (like Hispanic, Latino, Middle Eastern).
# [date&time] is in the format of yyyymmddHHMMSSFFF, showing the date and time an image was collected to UTKFace

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %%bash
# ls data
# # it seems crop_part1 conists of subset of data contained in UTKFace so we won't be using it.
# Out:
# UTKFace
# UTKFace.tar.gz

# %% [markdown]
# **Constants**

# %%
DATA_DIR = "data/UTKFace"
TRAIN_TEST_SPLIT = 0.7
IM_WIDTH = IM_HEIGHT = 198
ID_GENDER_MAP = {0: 'male', 1: 'female'}
GENDER_ID_MAP = dict((g, i) for i, g in ID_GENDER_MAP.items())
ID_RACE_MAP = {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'}
RACE_ID_MAP = dict((r, i) for i, r in ID_RACE_MAP.items())

ID_GENDER_MAP, GENDER_ID_MAP, ID_RACE_MAP, RACE_ID_MAP
# Out:
# ({0: 'male', 1: 'female'},
#  {'male': 0, 'female': 1},
#  {0: 'white', 1: 'black', 2: 'asian', 3: 'indian', 4: 'others'},
#  {'white': 0, 'black': 1, 'asian': 2, 'indian': 3, 'others': 4})

# %%
def parse_filepath(filepath):
    try:
        path, filename = os.path.split(filepath)
        filename, ext = os.path.splitext(filename)
        age, gender, race, _ = filename.split("_")
        return int(age), ID_GENDER_MAP[int(gender)], ID_RACE_MAP[int(race)]
    except Exception as e:
        print(filepath)
        return None, None, None

# %%
# create a pandas data frame of images, age, gender and race
files = glob.glob(os.path.join(DATA_DIR, "*.jpg"))

# %%
attributes = list(map(parse_filepath, files))
# Out:
# data/UTKFace/61_1_20170109142408075.jpg.chip.jpg
# data/UTKFace/61_1_20170109150557335.jpg.chip.jpg
# data/UTKFace/39_1_20170116174525125.jpg.chip.jpg

# %%
df = pd.DataFrame(attributes)
df['file'] = files
df.columns = ['age', 'gender', 'race', 'file']
df = df.dropna()
df.head()
# Out:
#     age  gender    race                                               file
# 0  26.0  female  indian  data/UTKFace/26_1_3_20170119180945883.jpg.chip...
# 1  29.0    male   black  data/UTKFace/29_0_1_20170116195112736.jpg.chip...
# 2  62.0    male   asian  data/UTKFace/62_0_2_20170112223958141.jpg.chip...
# 3  22.0    male   asian  data/UTKFace/22_0_2_20170116175910195.jpg.chip...
# 4  16.0  female  others  data/UTKFace/16_1_4_20170103233406635.jpg.chip...

# %% [markdown]
# # Exploratory analysis

# %%
df.describe()
# Out:
#                 age
# count  23705.000000
# mean      33.300907
# std       19.885708
# min        1.000000
# 25%       23.000000
# 50%       29.000000
# 75%       45.000000
# max      116.000000

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))
_ = sns.boxplot(data=df, x='gender', y='age', ax=ax1)
_ = sns.boxplot(data=df, x='race', y='age', ax=ax2)

# %% [markdown]
# From the plot we can see that most of people are within 10 and 55 years of age. Most probably, we'll discard the dataset for rest of the ages.

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=df, x='gender', y='age', hue='race')

# %%
df.groupby(by=['race', 'gender'])['age'].count().plot(kind='bar')

# %% [markdown]
# It turns out that there are many images of *white male* and *while female*. images from *others* category are very less in number compared to rest of the categories especially *white* category.
# Let's analyze our data from *age* perspective.

# %%
df['age'].hist()

# %%
df['age'].describe()
# Out:
# count    23705.000000
# mean        33.300907
# std         19.885708
# min          1.000000
# 25%         23.000000
# 50%         29.000000
# 75%         45.000000
# max        116.000000
# Name: age, dtype: float64

# %%
df = df[(df['age'] > 10) & (df['age'] < 65)]

# %% [markdown]
# # Data prep

# %%
p = np.random.RandomState(10).permutation(len(df))
print(p)
train_up_to = int(len(df) * TRAIN_TEST_SPLIT)
train_idx = p[:train_up_to]
test_idx = p[train_up_to:]

# split train_idx further into training and validation set
train_up_to = int(train_up_to * 0.7)
train_idx, valid_idx = train_idx[:train_up_to], train_idx[train_up_to:]

df['gender_id'] = df['gender'].map(lambda gender: GENDER_ID_MAP[gender])
df['race_id'] = df['race'].map(lambda race: RACE_ID_MAP[race])

max_age = df['age'].max()
len(train_idx), len(valid_idx), len(test_idx), max_age
# Out:
# [15086  9370   344 ... 17728  7293 17673]
# (9079, 3891, 5559, 64.0)

# %%
from keras.utils import to_categorical
from PIL import Image

def get_data_generator(df, indices, for_training, batch_size=16):
    images, ages, races, genders = [], [], [], []
    while True:
        for i in indices:
            r = df.iloc[i]
            file, age, race, gender = r['file'], r['age'], r['race_id'], r['gender_id']
            im = Image.open(file)
            im = im.resize((IM_WIDTH, IM_HEIGHT))
            im = np.array(im) / 255.0
            images.append(im)
            ages.append(age / max_age)
            races.append(to_categorical(race, len(RACE_ID_MAP)))
            genders.append(to_categorical(gender, 2))
            if len(images) >= batch_size:
                yield np.array(images), [np.array(ages), np.array(races), np.array(genders)]
                images, ages, races, genders = [], [], [], []
        if not for_training:
            break
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Model training

# %%
from keras.layers import Input, Dense, BatchNormalization, Conv2D, MaxPool2D, GlobalMaxPool2D, Dropout, Flatten
from keras.optimizers import SGD, RMSprop
from keras.models import Model
from keras import applications

vgg_model = applications.VGG16(weights='imagenet',
                               include_top=False,
                               input_shape=(IM_HEIGHT, IM_WIDTH, 3))

x = vgg_model.output
x = Flatten()(x)
x = Dense(4096, activation='relu')(x)

# for age calculation
age = Dense(units=128, activation='relu')(x)
age_output = Dense(units=1, activation='sigmoid', name='age_output')(age)

# for race prediction
race = Dense(units=128, activation='relu')(x)
race_output = Dense(units=len(RACE_ID_MAP), activation='softmax', name='race_output')(race)

# for gender prediction
gender = Dense(units=128, activation='relu')(x)
gender_output = Dense(units=len(GENDER_ID_MAP), activation='softmax', name='gender_output')(gender)

alpha1 = 10.
alpha2 = 0.00001

model = Model(inputs=vgg_model.input, outputs=[age_output, race_output, gender_output])
opt = RMSprop(lr=1e-5)
model.compile(optimizer=opt, 
              loss={'age_output': 'mse', 'race_output': 'categorical_crossentropy', 'gender_output': 'categorical_crossentropy'},
              loss_weights={'age_output': 0., 'race_output': alpha2, 'gender_output': alpha1},
              metrics={'age_output': 'mae', 'race_output': 'accuracy', 'gender_output': 'accuracy'})
# model.summary()

# %%
from keras.callbacks import ModelCheckpoint

batch_size = 64
valid_batch_size = 64
train_gen = get_data_generator(df, train_idx, for_training=True, batch_size=batch_size)
valid_gen = get_data_generator(df, valid_idx, for_training=True, batch_size=valid_batch_size)

callbacks = [
    ModelCheckpoint("./models/{}_{}_weighted_VGG_model.h5".format(alpha1,alpha2), monitor='val_loss')
]

history = model.fit_generator(train_gen,
                    steps_per_epoch=len(train_idx)//batch_size,
                    epochs=10,
                    callbacks=callbacks,
                    validation_data=valid_gen,
                    validation_steps=len(valid_idx)//valid_batch_size)
# Out:
# Epoch 1/10
# 141/141 [==============================] - 53s 378ms/step - loss: 3.3771 - age_output_loss: 0.0791 - race_output_loss: 1.4791 - gender_output_loss: 0.3377 - age_output_mean_absolute_error: 0.2135 - race_output_acc: 0.3994 - gender_output_acc: 0.8482 - val_loss: 1.7691 - val_age_output_loss: 0.0752 - val_race_output_loss: 1.4193 - val_gender_output_loss: 0.1769 - val_age_output_mean_absolute_error: 0.2049 - val_race_output_acc: 0.4159 - val_gender_output_acc: 0.9344
# Epoch 2/10
# 141/141 [==============================] - 48s 339ms/step - loss: 1.6417 - age_output_loss: 0.0772 - race_output_loss: 1.4138 - gender_output_loss: 0.1642 - age_output_mean_absolute_error: 0.2112 - race_output_acc: 0.4177 - gender_output_acc: 0.9392 - val_loss: 2.4840 - val_age_output_loss: 0.0802 - val_race_output_loss: 1.3841 - val_gender_output_loss: 0.2484 - val_age_output_mean_absolute_error: 0.2138 - val_race_output_acc: 0.4414 - val_gender_output_acc: 0.9018
# Epoch 3/10
# 141/141 [==============================] - 48s 341ms/step - loss: 1.1205 - age_output_loss: 0.0771 - race_output_loss: 1.3693 - gender_output_loss: 0.1121 - age_output_mean_absolute_error: 0.2101 - race_output_acc: 0.4454 - gender_output_acc: 0.9613 - val_loss: 1.5611 - val_age_output_loss: 0.0737 - val_race_output_loss: 1.3366 - val_gender_output_loss: 0.1561 - val_age_output_mean_absolute_error: 0.2021 - val_race_output_acc: 0.4773 - val_gender_output_acc: 0.9445
# Epoch 4/10
# 141/141 [==============================] - 48s 342ms/step - loss: 0.7354 - age_output_loss: 0.0805 - race_output_loss: 1.3285 - gender_output_loss: 0.0735 - age_output_mean_absolute_error: 0.2153 - race_output_acc: 0.4686 - gender_output_acc: 0.9782 - val_loss: 1.2940 - val_age_output_loss: 0.0824 - val_race_output_loss: 1.3011 - val_gender_output_loss: 0.1294 - val_age_output_mean_absolute_error: 0.2170 - val_race_output_acc: 0.5023 - val_gender_output_acc: 0.9596
# Epoch 5/10
# 141/141 [==============================] - 48s 343ms/step - loss: 0.4483 - age_output_loss: 0.0969 - race_output_loss: 1.2877 - gender_output_loss: 0.0448 - age_output_mean_absolute_error: 0.2410 - race_output_acc: 0.4922 - gender_output_acc: 0.9875 - val_loss: 1.5404 - val_age_output_loss: 0.1078 - val_race_output_loss: 1.2508 - val_gender_output_loss: 0.1540 - val_age_output_mean_absolute_error: 0.2546 - val_race_output_acc: 0.5219 - val_gender_output_acc: 0.9594
# Epoch 6/10
# 141/141 [==============================] - 48s 342ms/step - loss: 0.3761 - age_output_loss: 0.1050 - race_output_loss: 1.2486 - gender_output_loss: 0.0376 - age_output_mean_absolute_error: 0.2531 - race_output_acc: 0.5204 - gender_output_acc: 0.9891 - val_loss: 1.7013 - val_age_output_loss: 0.1105 - val_race_output_loss: 1.2134 - val_gender_output_loss: 0.1701 - val_age_output_mean_absolute_error: 0.2589 - val_race_output_acc: 0.5393 - val_gender_output_acc: 0.9583
# Epoch 7/10
# 141/141 [==============================] - 48s 344ms/step - loss: 0.2637 - age_output_loss: 0.1167 - race_output_loss: 1.2113 - gender_output_loss: 0.0264 - age_output_mean_absolute_error: 0.2700 - race_output_acc: 0.5380 - gender_output_acc: 0.9912 - val_loss: 1.9232 - val_age_output_loss: 0.1044 - val_race_output_loss: 1.1974 - val_gender_output_loss: 0.1923 - val_age_output_mean_absolute_error: 0.2488 - val_race_output_acc: 0.5500 - val_gender_output_acc: 0.9531
# Epoch 8/10
# 141/141 [==============================] - 48s 344ms/step - loss: 0.2337 - age_output_loss: 0.1173 - race_output_loss: 1.1849 - gender_output_loss: 0.0234 - age_output_mean_absolute_error: 0.2717 - race_output_acc: 0.5481 - gender_output_acc: 0.9932 - val_loss: 1.8883 - val_age_output_loss: 0.1116 - val_race_output_loss: 1.1689 - val_gender_output_loss: 0.1888 - val_age_output_mean_absolute_error: 0.2605 - val_race_output_acc: 0.5586 - val_gender_output_acc: 0.9576
# Epoch 9/10
# 141/141 [==============================] - 48s 344ms/step - loss: 0.1313 - age_output_loss: 0.1380 - race_output_loss: 1.1547 - gender_output_loss: 0.0131 - age_output_mean_absolute_error: 0.3014 - race_output_acc: 0.5660 - gender_output_acc: 0.9961 - val_loss: 2.7328 - val_age_output_loss: 0.1352 - val_race_output_loss: 1.1465 - val_gender_output_loss: 0.2733 - val_age_output_mean_absolute_error: 0.2926 - val_race_output_acc: 0.5594 - val_gender_output_acc: 0.9430
# Epoch 10/10
# 141/141 [==============================] - 49s 345ms/step - loss: 0.1913 - age_output_loss: 0.1371 - race_output_loss: 1.1384 - gender_output_loss: 0.0191 - age_output_mean_absolute_error: 0.2988 - race_output_acc: 0.5695 - gender_output_acc: 0.9934 - val_loss: 2.0268 - val_age_output_loss: 0.1214 - val_race_output_loss: 1.1384 - val_gender_output_loss: 0.2027 - val_age_output_mean_absolute_error: 0.2759 - val_race_output_acc: 0.5641 - val_gender_output_acc: 0.9565

# %%
def  plot_train_history(history):
    fig, axes = plt.subplots(1, 4, figsize=(20, 5))
    axes[0].plot(history.history['race_output_acc'], label='Race Train accuracy')
    axes[0].plot(history.history['val_race_output_acc'], label='Race Val accuracy')
    axes[0].set_xlabel('Epochs')
    axes[0].legend()
    
    axes[1].plot(history.history['gender_output_acc'], label='Gender Train accuracy')
    axes[1].plot(history.history['val_gender_output_acc'], label='Gener Val accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].legend()

    axes[2].plot(history.history['age_output_mean_absolute_error'], label='Age Train MAE')
    axes[2].plot(history.history['val_age_output_mean_absolute_error'], label='Age Val MAE')
    axes[2].set_xlabel('Epochs')
    axes[2].legend()  

    axes[3].plot(history.history['loss'], label='Training loss')
    axes[3].plot(history.history['val_loss'], label='Validation loss')
    axes[3].set_xlabel('Epochs')
    axes[3].legend()

plot_train_history(history)

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
dict(zip(model.metrics_names, model.evaluate_generator(test_gen, steps=len(test_idx)//128)))
# Out:
# {'loss': 2.2665295947429747,
#  'age_output_loss': 0.1224554480854855,
#  'race_output_loss': 1.1693039716676223,
#  'gender_output_loss': 0.22665178749796955,
#  'age_output_mean_absolute_error': 0.27755279145961587,
#  'race_output_acc': 0.5476017441860465,
#  'gender_output_acc': 0.9520348837209303}

# %%
test_gen = get_data_generator(df, test_idx, for_training=False, batch_size=128)
x_test, (age_true, race_true, gender_true)= next(test_gen)
age_pred, race_pred, gender_pred = model.predict_on_batch(x_test)

# %%
race_true, gender_true = race_true.argmax(axis=-1), gender_true.argmax(axis=-1)
race_pred, gender_pred = race_pred.argmax(axis=-1), gender_pred.argmax(axis=-1)
age_true = age_true * max_age
age_pred = age_pred * max_age

# %%
from sklearn.metrics import classification_report
print("Classification report for race")
print(classification_report(race_true, race_pred))

print("\nClassification report for gender")
print(classification_report(gender_true, gender_pred))
# Out:
# Classification report for race
#               precision    recall  f1-score   support
#
#            0       0.43      0.91      0.58        43
#            1       0.76      0.48      0.59        33
#            2       0.50      0.33      0.40        15
#            3       0.60      0.14      0.22        22
#            4       0.00      0.00      0.00        15
#
#     accuracy                           0.49       128
#    macro avg       0.46      0.37      0.36       128
# weighted avg       0.50      0.49      0.43       128
#
#
# Classification report for gender
#               precision    recall  f1-score   support
#
#            0       0.98      0.97      0.98        67
#            1       0.97      0.98      0.98        61
#
#     accuracy                           0.98       128
#    macro avg       0.98      0.98      0.98       128
# weighted avg       0.98      0.98      0.98       128

# %%
import math
n = 30
random_indices = np.random.permutation(n)
n_cols = 5
n_rows = math.ceil(n / n_cols)
fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 20))
for i, img_idx in enumerate(random_indices):
    ax = axes.flat[i]
    ax.imshow(x_test[img_idx])
    ax.set_title('a:{}, g:{}, r:{}'.format(int(age_pred[img_idx]), ID_GENDER_MAP[gender_pred[img_idx]], ID_RACE_MAP[race_pred[img_idx]]))
    ax.set_xlabel('a:{}, g:{}, r:{}'.format(int(age_true[img_idx]), ID_GENDER_MAP[gender_true[img_idx]], ID_RACE_MAP[race_true[img_idx]]))
    ax.set_xticks([])
    ax.set_yticks([])
